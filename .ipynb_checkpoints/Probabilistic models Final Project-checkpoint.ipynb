# %% [markdown]
# #### Probabilistic Models Final Project
# #### Modeling and Inferring Airline Passenger Satisfaction

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

import zipfile
import os
# Plot settings
plt.rcParams['figure.figsize'] = (12, 9)
plt.rcParams['font.size'] = 12

# %%
#loading the data
data=pd.read_csv("train.csv").drop('Unnamed: 0', axis=1)
data_raw=data.copy()

# %%
data['Gender']=data['Gender'].map(dict({'Male': 0, 'Female': 1}))
data['Customer Type']=data['Customer Type'].map(dict({'disloyal Customer': 0, 'Loyal Customer': 1}))
data['Type of Travel']=data['Type of Travel'].map(dict({'Personal Travel': 0, 'Business travel': 1}))
#data['Class']=data['Class'].map(dict({'Eco Plus': 0, 'Business': 1, 'Eco': 2}))
data['satisfaction']=data['satisfaction'].map(dict({'neutral or dissatisfied': 0, 'satisfied': 1}))

# %%
data
# Out:
#             id  Gender  Customer Type  Age  Type of Travel     Class  \
# 0        70172       0              1   13               0  Eco Plus
# 1         5047       0              0   25               1  Business
# 2       110028       1              1   26               1  Business
# 3        24026       1              1   25               1  Business
# 4       119299       0              1   61               1  Business
# ...        ...     ...            ...  ...             ...       ...
# 103899   94171       1              0   23               1       Eco
# 103900   73097       0              1   49               1  Business
# 103901   68825       0              0   30               1  Business
# 103902   54173       1              0   22               1       Eco
# 103903   62567       0              1   27               1  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                   460                      3
# 1                   235                      3
# 2                  1142                      2
# 3                   562                      2
# 4                   214                      3
# ...                 ...                    ...
# 103899              192                      2
# 103900             2347                      4
# 103901             1995                      1
# 103902             1000                      1
# 103903             1723                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  ...  \
# 0                                       4                       3  ...
# 1                                       2                       3  ...
# 2                                       2                       2  ...
# 3                                       5                       5  ...
# 4                                       3                       3  ...
# ...                                   ...                     ...  ...
# 103899                                  1                       2  ...
# 103900                                  4                       4  ...
# 103901                                  1                       1  ...
# 103902                                  1                       1  ...
# 103903                                  3                       3  ...
#
#         Inflight entertainment  On-board service  Leg room service  \
# 0                            5                 4                 3
# 1                            1                 1                 5
# 2                            5                 4                 3
# 3                            2                 2                 5
# 4                            3                 3                 4
# ...                        ...               ...               ...
# 103899                       2                 3                 1
# 103900                       5                 5                 5
# 103901                       4                 3                 2
# 103902                       1                 4                 5
# 103903                       1                 1                 1
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                      4                4                 5            5
# 1                      3                1                 4            1
# 2                      4                4                 4            5
# 3                      3                1                 4            2
# 4                      4                3                 3            3
# ...                  ...              ...               ...          ...
# 103899                 4                2                 3            2
# 103900                 5                5                 5            4
# 103901                 4                5                 5            4
# 103902                 1                5                 4            1
# 103903                 4                4                 3            1
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  satisfaction
# 0                               25                      18.0             0
# 1                                1                       6.0             0
# 2                                0                       0.0             1
# 3                               11                       9.0             0
# 4                                0                       0.0             1
# ...                            ...                       ...           ...
# 103899                           3                       0.0             0
# 103900                           0                       0.0             1
# 103901                           7                      14.0             0
# 103902                           0                       0.0             0
# 103903                           0                       0.0             0
#
# [103904 rows x 24 columns]

# %%
def oheColumn(oheData, columnName):
    oneHotEnc = OneHotEncoder(dtype=int, handle_unknown='ignore')

    oheDataColumn = oneHotEnc.fit_transform(oheData[[columnName]]).toarray()

    oheData[oneHotEnc.categories_[0]] = oheDataColumn

    for catCol in oneHotEnc.categories_[0]:
        oheData.rename(columns = {catCol:columnName+'_'+catCol}, inplace = True)
    
    return oheData

# %%
data = oheColumn(data, 'Class').drop('Class', axis=1)

# %%
data
# Out:
#             id  Gender  Customer Type  Age  Type of Travel  Flight Distance  \
# 0        70172       0              1   13               0              460
# 1         5047       0              0   25               1              235
# 2       110028       1              1   26               1             1142
# 3        24026       1              1   25               1              562
# 4       119299       0              1   61               1              214
# ...        ...     ...            ...  ...             ...              ...
# 103899   94171       1              0   23               1              192
# 103900   73097       0              1   49               1             2347
# 103901   68825       0              0   30               1             1995
# 103902   54173       1              0   22               1             1000
# 103903   62567       0              1   27               1             1723
#
#         Inflight wifi service  Departure/Arrival time convenient  \
# 0                           3                                  4
# 1                           3                                  2
# 2                           2                                  2
# 3                           2                                  5
# 4                           3                                  3
# ...                       ...                                ...
# 103899                      2                                  1
# 103900                      4                                  4
# 103901                      1                                  1
# 103902                      1                                  1
# 103903                      1                                  3
#
#         Ease of Online booking  Gate location  ...  Baggage handling  \
# 0                            3              1  ...                 4
# 1                            3              3  ...                 3
# 2                            2              2  ...                 4
# 3                            5              5  ...                 3
# 4                            3              3  ...                 4
# ...                        ...            ...  ...               ...
# 103899                       2              3  ...                 4
# 103900                       4              4  ...                 5
# 103901                       1              3  ...                 4
# 103902                       1              5  ...                 1
# 103903                       3              3  ...                 4
#
#         Checkin service  Inflight service  Cleanliness  \
# 0                     4                 5            5
# 1                     1                 4            1
# 2                     4                 4            5
# 3                     1                 4            2
# 4                     3                 3            3
# ...                 ...               ...          ...
# 103899                2                 3            2
# 103900                5                 5            4
# 103901                5                 5            4
# 103902                5                 4            1
# 103903                4                 3            1
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  satisfaction  \
# 0                               25                      18.0             0
# 1                                1                       6.0             0
# 2                                0                       0.0             1
# 3                               11                       9.0             0
# 4                                0                       0.0             1
# ...                            ...                       ...           ...
# 103899                           3                       0.0             0
# 103900                           0                       0.0             1
# 103901                           7                      14.0             0
# 103902                           0                       0.0             0
# 103903                           0                       0.0             0
#
#         Class_Business  Class_Eco  Class_Eco Plus
# 0                    0          0               1
# 1                    1          0               0
# 2                    1          0               0
# 3                    1          0               0
# 4                    1          0               0
# ...                ...        ...             ...
# 103899               0          1               0
# 103900               1          0               0
# 103901               1          0               0
# 103902               0          1               0
# 103903               1          0               0
#
# [103904 rows x 26 columns]

# %%
print(data.iloc[:,0:27].isna().sum())
# Out:
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# Class_Business                         0
# Class_Eco                              0
# Class_Eco Plus                         0
# dtype: int64

# %%
#Filling in nan values
data['Arrival Delay in Minutes']=data['Arrival Delay in Minutes'].fillna(0)

# %%
print(data.iloc[:,0:27].isna().sum())
# Out:
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# Class_Business                       0
# Class_Eco                            0
# Class_Eco Plus                       0
# dtype: int64

# %%
data=data.drop_duplicates()

# %%
data
# Out:
#             id  Gender  Customer Type  Age  Type of Travel  Flight Distance  \
# 0        70172       0              1   13               0              460
# 1         5047       0              0   25               1              235
# 2       110028       1              1   26               1             1142
# 3        24026       1              1   25               1              562
# 4       119299       0              1   61               1              214
# ...        ...     ...            ...  ...             ...              ...
# 103899   94171       1              0   23               1              192
# 103900   73097       0              1   49               1             2347
# 103901   68825       0              0   30               1             1995
# 103902   54173       1              0   22               1             1000
# 103903   62567       0              1   27               1             1723
#
#         Inflight wifi service  Departure/Arrival time convenient  \
# 0                           3                                  4
# 1                           3                                  2
# 2                           2                                  2
# 3                           2                                  5
# 4                           3                                  3
# ...                       ...                                ...
# 103899                      2                                  1
# 103900                      4                                  4
# 103901                      1                                  1
# 103902                      1                                  1
# 103903                      1                                  3
#
#         Ease of Online booking  Gate location  ...  Baggage handling  \
# 0                            3              1  ...                 4
# 1                            3              3  ...                 3
# 2                            2              2  ...                 4
# 3                            5              5  ...                 3
# 4                            3              3  ...                 4
# ...                        ...            ...  ...               ...
# 103899                       2              3  ...                 4
# 103900                       4              4  ...                 5
# 103901                       1              3  ...                 4
# 103902                       1              5  ...                 1
# 103903                       3              3  ...                 4
#
#         Checkin service  Inflight service  Cleanliness  \
# 0                     4                 5            5
# 1                     1                 4            1
# 2                     4                 4            5
# 3                     1                 4            2
# 4                     3                 3            3
# ...                 ...               ...          ...
# 103899                2                 3            2
# 103900                5                 5            4
# 103901                5                 5            4
# 103902                5                 4            1
# 103903                4                 3            1
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  satisfaction  \
# 0                               25                      18.0             0
# 1                                1                       6.0             0
# 2                                0                       0.0             1
# 3                               11                       9.0             0
# 4                                0                       0.0             1
# ...                            ...                       ...           ...
# 103899                           3                       0.0             0
# 103900                           0                       0.0             1
# 103901                           7                      14.0             0
# 103902                           0                       0.0             0
# 103903                           0                       0.0             0
#
#         Class_Business  Class_Eco  Class_Eco Plus
# 0                    0          0               1
# 1                    1          0               0
# 2                    1          0               0
# 3                    1          0               0
# 4                    1          0               0
# ...                ...        ...             ...
# 103899               0          1               0
# 103900               1          0               0
# 103901               1          0               0
# 103902               0          1               0
# 103903               1          0               0
#
# [103904 rows x 26 columns]

# %%
corrMatrix = data.corr()
#print(corrMatrix)
sns.heatmap(corrMatrix, annot=True,)
# Out:
# <AxesSubplot:>

# %%
data1=data_raw.loc[:, ['Type of Travel', 'Inflight wifi service',
       'Ease of Online booking', 'Food and drink', 'Online boarding', 'On-board service',
       'Baggage handling', 'Inflight service', 'Cleanliness',
       'Departure Delay in Minutes', 'Arrival Delay in Minutes',
       'satisfaction', 'Class','Inflight entertainment','Seat comfort']]#data.drop("id", axis=1) 'Inflight entertainment''Seat comfort'

# %%
data1
# Out:
#          Type of Travel  Inflight wifi service  Ease of Online booking  \
# 0       Personal Travel                      3                       3
# 1       Business travel                      3                       3
# 2       Business travel                      2                       2
# 3       Business travel                      2                       5
# 4       Business travel                      3                       3
# ...                 ...                    ...                     ...
# 103899  Business travel                      2                       2
# 103900  Business travel                      4                       4
# 103901  Business travel                      1                       1
# 103902  Business travel                      1                       1
# 103903  Business travel                      1                       3
#
#         Food and drink  Online boarding  On-board service  Baggage handling  \
# 0                    5                3                 4                 4
# 1                    1                3                 1                 3
# 2                    5                5                 4                 4
# 3                    2                2                 2                 3
# 4                    4                5                 3                 4
# ...                ...              ...               ...               ...
# 103899               2                2                 3                 4
# 103900               2                4                 5                 5
# 103901               4                1                 3                 4
# 103902               1                1                 4                 1
# 103903               1                1                 1                 4
#
#         Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                      5            5                          25
# 1                      4            1                           1
# 2                      4            5                           0
# 3                      4            2                          11
# 4                      3            3                           0
# ...                  ...          ...                         ...
# 103899                 3            2                           3
# 103900                 5            4                           0
# 103901                 5            4                           7
# 103902                 4            1                           0
# 103903                 3            1                           0
#
#         Arrival Delay in Minutes             satisfaction     Class  \
# 0                           18.0  neutral or dissatisfied  Eco Plus
# 1                            6.0  neutral or dissatisfied  Business
# 2                            0.0                satisfied  Business
# 3                            9.0  neutral or dissatisfied  Business
# 4                            0.0                satisfied  Business
# ...                          ...                      ...       ...
# 103899                       0.0  neutral or dissatisfied       Eco
# 103900                       0.0                satisfied  Business
# 103901                      14.0  neutral or dissatisfied  Business
# 103902                       0.0  neutral or dissatisfied       Eco
# 103903                       0.0  neutral or dissatisfied  Business
#
#         Inflight entertainment  Seat comfort
# 0                            5             5
# 1                            1             1
# 2                            5             5
# 3                            2             2
# 4                            3             5
# ...                        ...           ...
# 103899                       2             2
# 103900                       5             5
# 103901                       4             5
# 103902                       1             1
# 103903                       1             1
#
# [103904 rows x 15 columns]

# %%
from pgmpy.estimators import PC
from pgmpy.estimators.CITests import chi_square
est = PC(data1)
# print(est.estimate(significance_level=0.01).edges())

# %%
from pgmpy.estimators import HillClimbSearch
from pgmpy.estimators import BDeuScore, K2Score, BicScore
from pgmpy.models import BayesianModel
hc = HillClimbSearch(data1)
best_model = hc.estimate(scoring_method=BicScore(data1))
print(best_model.edges())
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# [('Type of Travel', 'Ease of Online booking'), ('Type of Travel', 'satisfaction'), ('Type of Travel', 'On-board service'), ('Type of Travel', 'Online boarding'), ('Type of Travel', 'Inflight service'), ('Inflight wifi service', 'Ease of Online booking'), ('Ease of Online booking', 'Cleanliness'), ('Ease of Online booking', 'Food and drink'), ('Food and drink', 'Cleanliness'), ('Food and drink', 'Inflight entertainment'), ('Food and drink', 'Seat comfort'), ('Online boarding', 'Inflight wifi service'), ('Online boarding', 'Cleanliness'), ('Online boarding', 'Ease of Online booking'), ('Online boarding', 'Food and drink'), ('On-board service', 'Inflight service'), ('On-board service', 'Baggage handling'), ('Baggage handling', 'Inflight wifi service'), ('Inflight service', 'Inflight entertainment'), ('Inflight service', 'Baggage handling'), ('Cleanliness', 'Inflight entertainment'), ('Cleanliness', 'Seat comfort'), ('satisfaction', 'Online boarding'), ('satisfaction', 'Inflight wifi service'), ('satisfaction', 'On-board service'), ('satisfaction', 'Seat comfort'), ('satisfaction', 'Baggage handling'), ('satisfaction', 'Inflight service'), ('satisfaction', 'Ease of Online booking'), ('satisfaction', 'Food and drink'), ('Class', 'Type of Travel'), ('Class', 'satisfaction'), ('Class', 'Inflight wifi service'), ('Class', 'Inflight service'), ('Class', 'On-board service'), ('Class', 'Online boarding')]

# %%
import networkx as nx
import matplotlib.pyplot as plt


G = nx.DiGraph(best_model.edges())

for layer, nodes in enumerate(nx.topological_generations(G)):
    # `multipartite_layout` expects the layer as a node attribute, so add the
    # numeric layer value as a node attribute
    for node in nodes:
        G.nodes[node]["layer"] = layer

# Compute the multipartite_layout using the "layer" node attribute
# pos = nx.multipartite_layout(G, subset_key="layer")
pos=nx.circular_layout(G, scale=1, center=None, dim=2)
# nx.spring_layout(G)#nx.nx_pydot.graphviz_layout(G)
# 
fig, ax = plt.subplots()
nx.draw_networkx(G, pos=pos, ax=ax)
ax.set_title("DAG layout in topological order")
fig.tight_layout()
plt.show()

# %% [markdown]
# the features which we are inferring are\
#
# 1)Satisfaction\
# 2)Type of Travel

# %%
#Maximum likelihood estimator

# %%
from pgmpy.models import BayesianModel

model = BayesianModel(best_model.edges())

# %%
from pgmpy.estimators import MaximumLikelihoodEstimator
mle = MaximumLikelihoodEstimator(model, data1)
# print(mle.estimate_cpd('satisfaction'))  # unconditional
mle_df=mle.estimate_cpd('satisfaction')

# %%
print(mle_df)
# Out:
# +---------------------------------------+---------------------------------+---------------------------------+---------------------------------+---------------------------------+---------------------------------+---------------------------------+
# | Class                                 | Class(Business)                 | Class(Business)                 | Class(Eco)                      | Class(Eco)                      | Class(Eco Plus)                 | Class(Eco Plus)                 |
# +---------------------------------------+---------------------------------+---------------------------------+---------------------------------+---------------------------------+---------------------------------+---------------------------------+
# | Type of Travel                        | Type of Travel(Business travel) | Type of Travel(Personal Travel) | Type of Travel(Business travel) | Type of Travel(Personal Travel) | Type of Travel(Business travel) | Type of Travel(Personal Travel) |
# +---------------------------------------+---------------------------------+---------------------------------+---------------------------------+---------------------------------+---------------------------------+---------------------------------+
# | satisfaction(neutral or dissatisfied) | 0.27979908829984806             | 0.8771521637971149              | 0.7038412038412039              | 0.898147095600773               | 0.6068574374838877              | 0.9133463360267484              |
# +---------------------------------------+---------------------------------+---------------------------------+---------------------------------+---------------------------------+---------------------------------+---------------------------------+
# | satisfaction(satisfied)               | 0.720200911700152               | 0.12284783620288506             | 0.29615879615879614             | 0.101852904399227               | 0.3931425625161124              | 0.0866536639732516              |
# +---------------------------------------+---------------------------------+---------------------------------+---------------------------------+---------------------------------+---------------------------------+---------------------------------+

# %%
from pgmpy.factors.discrete.CPD import TabularCPD

def print_full(cpd):
    backup = TabularCPD._truncate_strtable
    TabularCPD._truncate_strtable = lambda self, x: x
    print(cpd)
    TabularCPD._truncate_strtable = backup

# %%
# print_full(mle_df)

# %%
mle.get_parameters()
# Out:
# [<TabularCPD representing P(Type of Travel:2 | Class:3) at 0x1e0d6ef0a90>,
#  <TabularCPD representing P(Ease of Online booking:6 | Inflight wifi service:6, Online boarding:6, Type of Travel:2, satisfaction:2) at 0x1e0d6f6ca60>,
#  <TabularCPD representing P(satisfaction:2 | Class:3, Type of Travel:2) at 0x1e0d6f60f10>,
#  <TabularCPD representing P(On-board service:6 | Class:3, Type of Travel:2, satisfaction:2) at 0x1e0d6ee7d30>,
#  <TabularCPD representing P(Online boarding:6 | Class:3, Type of Travel:2, satisfaction:2) at 0x1e0d6efbdc0>,
#  <TabularCPD representing P(Inflight service:6 | Class:3, On-board service:6, Type of Travel:2, satisfaction:2) at 0x1e0d6f6c820>,
#  <TabularCPD representing P(Inflight wifi service:6 | Baggage handling:5, Class:3, Online boarding:6, satisfaction:2) at 0x1e0d6eddfa0>,
#  <TabularCPD representing P(Cleanliness:6 | Ease of Online booking:6, Food and drink:6, Online boarding:6) at 0x1e0d6f60eb0>,
#  <TabularCPD representing P(Food and drink:6 | Ease of Online booking:6, Online boarding:6, satisfaction:2) at 0x1e0d6efba00>,
#  <TabularCPD representing P(Inflight entertainment:6 | Cleanliness:6, Food and drink:6, Inflight service:6) at 0x1e0d6ee7460>,
#  <TabularCPD representing P(Seat comfort:6 | Cleanliness:6, Food and drink:6, satisfaction:2) at 0x1e0d6edd0a0>,
#  <TabularCPD representing P(Baggage handling:5 | Inflight service:6, On-board service:6, satisfaction:2) at 0x1e0d6f609d0>,
#  <TabularCPD representing P(Class:3) at 0x1e0d6ef0b50>]

# %%
print(mle.estimate_cpd('Class'))
# Out:
# +-----------------+-----------+
# | Class(Business) | 0.478145  |
# +-----------------+-----------+
# | Class(Eco)      | 0.449765  |
# +-----------------+-----------+
# | Class(Eco Plus) | 0.0720891 |
# +-----------------+-----------+

# %%
best_model.edges()
# Out:
# OutEdgeView([('Type of Travel', 'Ease of Online booking'), ('Type of Travel', 'satisfaction'), ('Type of Travel', 'On-board service'), ('Type of Travel', 'Online boarding'), ('Type of Travel', 'Inflight service'), ('Inflight wifi service', 'Ease of Online booking'), ('Ease of Online booking', 'Cleanliness'), ('Ease of Online booking', 'Food and drink'), ('Food and drink', 'Cleanliness'), ('Food and drink', 'Inflight entertainment'), ('Food and drink', 'Seat comfort'), ('Online boarding', 'Inflight wifi service'), ('Online boarding', 'Cleanliness'), ('Online boarding', 'Ease of Online booking'), ('Online boarding', 'Food and drink'), ('On-board service', 'Inflight service'), ('On-board service', 'Baggage handling'), ('Baggage handling', 'Inflight wifi service'), ('Inflight service', 'Inflight entertainment'), ('Inflight service', 'Baggage handling'), ('Cleanliness', 'Inflight entertainment'), ('Cleanliness', 'Seat comfort'), ('satisfaction', 'Online boarding'), ('satisfaction', 'Inflight wifi service'), ('satisfaction', 'On-board service'), ('satisfaction', 'Seat comfort'), ('satisfaction', 'Baggage handling'), ('satisfaction', 'Inflight service'), ('satisfaction', 'Ease of Online booking'), ('satisfaction', 'Food and drink'), ('Class', 'Type of Travel'), ('Class', 'satisfaction'), ('Class', 'Inflight wifi service'), ('Class', 'Inflight service'), ('Class', 'On-board service'), ('Class', 'Online boarding')])

# %%
import networkx as nx

# Create a directed graph
DG = nx.DiGraph()
DG.add_edges_from(list(best_model.edges()))

# Create the graph skeleton (undirected graph)
UG = DG.to_undirected()

# Moralize the graph
for node in DG.nodes:
    parents = [pred for pred in DG.predecessors(node)]
    for i, parent1 in enumerate(parents):
        for parent2 in parents[i + 1:]:
            if not UG.has_edge(parent1, parent2):
                UG.add_edge(parent1, parent2)

# Triangulate the graph
def find_chordal_graph(graph):
    triangulated_graph = graph.copy()
#     cliques = nx.chordal_graph_cliques(triangulated_graph)
#     fill_in_edges = nx.chordal_graph_fill_in_edges(triangulated_graph)
    fill_in_edges = nx.complete_to_chordal_graph(triangulated_graph)

#     for **a in fill_in_edges:
#         print(**a)
    print(list(fill_in_edges)[1])
    for u, v in list(fill_in_edges)[1].items():
        triangulated_graph.add_edge(u, v)

    return triangulated_graph

triangulated_UG = find_chordal_graph(UG)

print("Directed Graph:")
print(DG.edges)

print("\nGraph Skeleton:")
print(UG.edges)

print("\nMoralized Graph:")
print(UG.edges)

print("\nTriangulated Graph:")
print(triangulated_UG.edges)
# Out:
# {'Type of Travel': 13, 'Ease of Online booking': 12, 'satisfaction': 11, 'On-board service': 7, 'Online boarding': 10, 'Inflight service': 9, 'Inflight wifi service': 8, 'Cleanliness': 4, 'Food and drink': 3, 'Inflight entertainment': 2, 'Seat comfort': 1, 'Baggage handling': 5, 'Class': 6}
# Directed Graph:
# [('Type of Travel', 'Ease of Online booking'), ('Type of Travel', 'satisfaction'), ('Type of Travel', 'On-board service'), ('Type of Travel', 'Online boarding'), ('Type of Travel', 'Inflight service'), ('Ease of Online booking', 'Cleanliness'), ('Ease of Online booking', 'Food and drink'), ('satisfaction', 'Online boarding'), ('satisfaction', 'Inflight wifi service'), ('satisfaction', 'On-board service'), ('satisfaction', 'Seat comfort'), ('satisfaction', 'Baggage handling'), ('satisfaction', 'Inflight service'), ('satisfaction', 'Ease of Online booking'), ('satisfaction', 'Food and drink'), ('On-board service', 'Inflight service'), ('On-board service', 'Baggage handling'), ('Online boarding', 'Inflight wifi service'), ('Online boarding', 'Cleanliness'), ('Online boarding', 'Ease of Online booking'), ('Online boarding', 'Food and drink'), ('Inflight service', 'Inflight entertainment'), ('Inflight service', 'Baggage handling'), ('Inflight wifi service', 'Ease of Online booking'), ('Cleanliness', 'Inflight entertainment'), ('Cleanliness', 'Seat comfort'), ('Food and drink', 'Cleanliness'), ('Food and drink', 'Inflight entertainment'), ('Food and drink', 'Seat comfort'), ('Baggage handling', 'Inflight wifi service'), ('Class', 'Type of Travel'), ('Class', 'satisfaction'), ('Class', 'Inflight wifi service'), ('Class', 'Inflight service'), ('Class', 'On-board service'), ('Class', 'Online boarding')]
#
# Graph Skeleton:
# [('Type of Travel', 'Ease of Online booking'), ('Type of Travel', 'satisfaction'), ('Type of Travel', 'On-board service'), ('Type of Travel', 'Online boarding'), ('Type of Travel', 'Inflight service'), ('Type of Travel', 'Class'), ('Type of Travel', 'Inflight wifi service'), ('Ease of Online booking', 'Cleanliness'), ('Ease of Online booking', 'Food and drink'), ('Ease of Online booking', 'satisfaction'), ('Ease of Online booking', 'Online boarding'), ('Ease of Online booking', 'Inflight wifi service'), ('satisfaction', 'Online boarding'), ('satisfaction', 'Inflight wifi service'), ('satisfaction', 'On-board service'), ('satisfaction', 'Seat comfort'), ('satisfaction', 'Baggage handling'), ('satisfaction', 'Inflight service'), ('satisfaction', 'Food and drink'), ('satisfaction', 'Class'), ('satisfaction', 'Cleanliness'), ('On-board service', 'Inflight service'), ('On-board service', 'Baggage handling'), ('On-board service', 'Class'), ('Online boarding', 'Inflight wifi service'), ('Online boarding', 'Cleanliness'), ('Online boarding', 'Food and drink'), ('Online boarding', 'Class'), ('Online boarding', 'Baggage handling'), ('Inflight service', 'Inflight entertainment'), ('Inflight service', 'Baggage handling'), ('Inflight service', 'Class'), ('Inflight service', 'Food and drink'), ('Inflight service', 'Cleanliness'), ('Inflight wifi service', 'Baggage handling'), ('Inflight wifi service', 'Class'), ('Cleanliness', 'Inflight entertainment'), ('Cleanliness', 'Seat comfort'), ('Cleanliness', 'Food and drink'), ('Food and drink', 'Inflight entertainment'), ('Food and drink', 'Seat comfort'), ('Baggage handling', 'Class')]
#
# Moralized Graph:
# [('Type of Travel', 'Ease of Online booking'), ('Type of Travel', 'satisfaction'), ('Type of Travel', 'On-board service'), ('Type of Travel', 'Online boarding'), ('Type of Travel', 'Inflight service'), ('Type of Travel', 'Class'), ('Type of Travel', 'Inflight wifi service'), ('Ease of Online booking', 'Cleanliness'), ('Ease of Online booking', 'Food and drink'), ('Ease of Online booking', 'satisfaction'), ('Ease of Online booking', 'Online boarding'), ('Ease of Online booking', 'Inflight wifi service'), ('satisfaction', 'Online boarding'), ('satisfaction', 'Inflight wifi service'), ('satisfaction', 'On-board service'), ('satisfaction', 'Seat comfort'), ('satisfaction', 'Baggage handling'), ('satisfaction', 'Inflight service'), ('satisfaction', 'Food and drink'), ('satisfaction', 'Class'), ('satisfaction', 'Cleanliness'), ('On-board service', 'Inflight service'), ('On-board service', 'Baggage handling'), ('On-board service', 'Class'), ('Online boarding', 'Inflight wifi service'), ('Online boarding', 'Cleanliness'), ('Online boarding', 'Food and drink'), ('Online boarding', 'Class'), ('Online boarding', 'Baggage handling'), ('Inflight service', 'Inflight entertainment'), ('Inflight service', 'Baggage handling'), ('Inflight service', 'Class'), ('Inflight service', 'Food and drink'), ('Inflight service', 'Cleanliness'), ('Inflight wifi service', 'Baggage handling'), ('Inflight wifi service', 'Class'), ('Cleanliness', 'Inflight entertainment'), ('Cleanliness', 'Seat comfort'), ('Cleanliness', 'Food and drink'), ('Food and drink', 'Inflight entertainment'), ('Food and drink', 'Seat comfort'), ('Baggage handling', 'Class')]
#
# Triangulated Graph:
# [('Type of Travel', 'Ease of Online booking'), ('Type of Travel', 'satisfaction'), ('Type of Travel', 'On-board service'), ('Type of Travel', 'Online boarding'), ('Type of Travel', 'Inflight service'), ('Type of Travel', 'Class'), ('Type of Travel', 'Inflight wifi service'), ('Type of Travel', 13), ('Ease of Online booking', 'Cleanliness'), ('Ease of Online booking', 'Food and drink'), ('Ease of Online booking', 'satisfaction'), ('Ease of Online booking', 'Online boarding'), ('Ease of Online booking', 'Inflight wifi service'), ('Ease of Online booking', 12), ('satisfaction', 'Online boarding'), ('satisfaction', 'Inflight wifi service'), ('satisfaction', 'On-board service'), ('satisfaction', 'Seat comfort'), ('satisfaction', 'Baggage handling'), ('satisfaction', 'Inflight service'), ('satisfaction', 'Food and drink'), ('satisfaction', 'Class'), ('satisfaction', 'Cleanliness'), ('satisfaction', 11), ('On-board service', 'Inflight service'), ('On-board service', 'Baggage handling'), ('On-board service', 'Class'), ('On-board service', 7), ('Online boarding', 'Inflight wifi service'), ('Online boarding', 'Cleanliness'), ('Online boarding', 'Food and drink'), ('Online boarding', 'Class'), ('Online boarding', 'Baggage handling'), ('Online boarding', 10), ('Inflight service', 'Inflight entertainment'), ('Inflight service', 'Baggage handling'), ('Inflight service', 'Class'), ('Inflight service', 'Food and drink'), ('Inflight service', 'Cleanliness'), ('Inflight service', 9), ('Inflight wifi service', 'Baggage handling'), ('Inflight wifi service', 'Class'), ('Inflight wifi service', 8), ('Cleanliness', 'Inflight entertainment'), ('Cleanliness', 'Seat comfort'), ('Cleanliness', 'Food and drink'), ('Cleanliness', 4), ('Food and drink', 'Inflight entertainment'), ('Food and drink', 'Seat comfort'), ('Food and drink', 3), ('Inflight entertainment', 2), ('Seat comfort', 1), ('Baggage handling', 'Class'), ('Baggage handling', 5), ('Class', 6)]
